# %% [markdown]
# # Using GeoPandas to plot the US boundaries
# ##### Author: John Mays

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
usa = gpd.read_file("../data/map/US_State_Boundaries.geojson")

# %%
usa.columns
# Out:
# Index(['FID', 'OBJECTID', 'NAME', 'STATE_ABBR', 'STATE_FIPS', 'ORDER_ADM',
#        'MONTH_ADM', 'DAY_ADM', 'YEAR_ADM', 'TYPE', 'POP', 'SQ_MILES',
#        'PRIM_MILES', 'Shape_Leng', 'Shape__Area', 'Shape__Length', 'geometry'],
#       dtype='object')

# %%
# usa['geometry'][24] # outline of Texas

# %%
# without Alaska: 
longitude_range = (-127, -66)
latitude_range = (23.5, 50)

degrees_per_inch = 2.5

width = (longitude_range[1] - longitude_range[0]) / degrees_per_inch
height = (latitude_range[1] - latitude_range[0]) / degrees_per_inch

# plt.figure(figsize=(18, 12), dpi=150)
usa.plot(color="white", edgecolor="black", linewidth=0.5,
         figsize=(width, height))
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.xlim(longitude_range)
plt.ylim(latitude_range)
plt.title("Rainy Cities in the Continental U.S.A.")
plt.show()
